# %%
import pandas as pd 
import psycopg2
import altair as alt

# %%
db_host = "energy-monitor.c57vkec7dkkx.eu-west-2.rds.amazonaws.com"
db_username = "postgres"
db_password = "password"
db_port = "5432"
db_name = "postgres"

# %%
conn = psycopg2.connect(
           host=db_host,
           database=db_name,
           user=db_username,
           password=db_password,
           port=db_port
       )


Demand_query = "SELECT * FROM Demand" 
Gen_query = "SELECT * FROM Generation" 
Cost_query = "SELECT * FROM Cost"
carbon_query = "SELECT * FROM Carbon"
Demand_df = pd.read_sql_query(Demand_query, conn)
Cost_df = pd.read_sql_query(Cost_query, conn)
Gen_df = pd.read_sql_query(Gen_query, conn)
carbon_df = pd.read_sql_query(carbon_query, conn)


if conn:
    conn.close()
    print("Database connection closed.")
# Out:
# /var/folders/81/f1rdgkd103zcv48_n3ps90c40000gp/T/ipykernel_61773/2580455365.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Demand_df = pd.read_sql_query(Demand_query, conn)
# /var/folders/81/f1rdgkd103zcv48_n3ps90c40000gp/T/ipykernel_61773/2580455365.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Cost_df = pd.read_sql_query(Cost_query, conn)
# /var/folders/81/f1rdgkd103zcv48_n3ps90c40000gp/T/ipykernel_61773/2580455365.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Gen_df = pd.read_sql_query(Gen_query, conn)
# Database connection closed.
# /var/folders/81/f1rdgkd103zcv48_n3ps90c40000gp/T/ipykernel_61773/2580455365.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   carbon_df = pd.read_sql_query(carbon_query, conn)

# %%
#print(Demand_df.head())
#rint(Cost_df.head())
#print(Gen_df)
#print(carbon_df.loc[carbon_df["carbon_level"]=="moderate"])
#print(carbon_df.loc[carbon_df["carbon_level"] == "low"])
#groups = Gen_df["fuel_type"].unique()
#print(groups)

# %%
Cost_df
# Out:
#    publish_date  settlement_period  sell_price  buy_price
# 0    2024-08-15                 32   -0.840000  -0.840000
# 1    2024-08-15                 31   -2.270000  -2.270000
# 2    2024-08-15                 30  -21.280000 -21.280000
# 3    2024-08-15                 29    0.000000   0.000000
# 4    2024-08-15                 28   85.000000  85.000000
# 5    2024-08-15                 27   85.000000  85.000000
# 6    2024-08-15                 26  -18.860000 -18.860000
# 7    2024-08-15                 25  -18.860000 -18.860000
# 8    2024-08-15                 24  -18.860000 -18.860000
# 9    2024-08-15                 23  -18.860000 -18.860000
# 10   2024-08-15                 22  -18.860000 -18.860000
# 11   2024-08-15                 21   -8.260000  -8.260000
# 12   2024-08-15                 20    6.720000   6.720000
# 13   2024-08-15                 19    6.090000   6.090000
# 14   2024-08-15                 18   10.320000  10.320000
# 15   2024-08-15                 17   11.500000  11.500000
# 16   2024-08-15                 16   36.940000  36.940000
# 17   2024-08-15                 15   31.750000  31.750000
# 18   2024-08-15                 14   48.310000  48.310000
# 19   2024-08-15                 13   47.780000  47.780000
# 20   2024-08-15                 12   89.000000  89.000000
# 21   2024-08-15                 11   88.000000  88.000000
# 22   2024-08-15                 10   89.000000  89.000000
# 23   2024-08-15                 45   84.980000  84.980000
# 24   2024-08-15                 48   93.000000  93.000000
# 25   2024-08-15                 47   93.000000  93.000000
# 26   2024-08-15                 46   93.000000  93.000000
# 27   2024-08-16                 20   86.450000  86.450000
# 28   2024-08-16                 19   93.000000  93.000000
# 29   2024-08-16                 18   93.000000  93.000000
# 30   2024-08-16                 17   93.000000  93.000000
# 31   2024-08-16                 16   93.000000  93.000000
# 32   2024-08-15                 33    0.000000   0.000000
# 33   2024-08-16                 15   93.000000  93.000000
# 34   2024-08-16                 14   74.240000  74.240000
# 35   2024-08-16                 13   53.270000  53.270000
# 36   2024-08-15                  9   91.500000  91.500000
# 37   2024-08-16                 12   52.000000  52.000000
# 38   2024-08-16                 11    0.850000   0.850000
# 39   2024-08-16                 10    0.872331   0.872331
# 40   2024-08-16                  9   90.910000  90.910000
# 41   2024-08-16                 21    0.000000   0.000000
# 42   2024-08-16                 22    0.000000   0.000000
# 43   2024-08-16                  8   93.000000  93.000000
# 44   2024-08-16                  7   92.900000  92.900000
# 45   2024-08-16                  6   90.870000  90.870000
# 46   2024-08-16                  5   89.000000  89.000000
# 47   2024-08-16                  4   54.440000  54.440000
# 48   2024-08-16                  3    1.210000   1.210000
# 49   2024-08-16                  2   56.600000  56.600000
# 50   2024-08-16                  1   93.000000  93.000000

# %%
chart = alt.Chart(Gen_df[["publish_time", "generated", "fuel_type"]]).mark_line().encode(
    x="publish_time", y="generated",color="fuel_type")
chart
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# File ~/Documents/GitHub/Coursework/energy_monitor/.venv/lib/python3.12/site-packages/altair/vegalite/v5/api.py:3772, in Chart.to_dict(self, validate, format, ignore, context)
#    3770     copy.data = core.InlineData(values=[{}])
#    3771     return super(Chart, copy).to_dict(**kwds)
# -> 3772 return super().to_dict(**kwds)
#
# File ~/Documents/GitHub/Coursework/energy_monitor/.venv/lib/python3.12/site-packages/altair/vegalite/v5/api.py:1798, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    1795     except TypeError:
#    1796         # Non-narwhalifiable type supported by Altair, such as dict
#    1797         data = original_data
# -> 1798     copy.data = _prepare_data(data, context)
#    1799     context["data"] = data
#    1801 # remaining to_dict calls are not at top level
#
# File ~/Documents/GitHub/Coursework/energy_monitor/.venv/lib/python3.12/site-packages/altair/vegalite/v5/api.py:275, in _prepare_data(data, context)
#     273 elif not isinstance(data, dict) and _is_data_type(data):
#     274     if func := data_transformers.get():
# --> 275         data = func(data)
#     277 # convert string input to a URLData
#     278 elif isinstance(data, str):
#
# File ~/Documents/GitHub/Coursework/energy_monitor/.venv/lib/python3.12/site-packages/altair/vegalite/data.py:42, in default_data_transformer(data, max_rows)
#      39     return pipe
#      41 else:
# ---> 42     return to_values(limit_rows(data, max_rows=max_rows))
#
# File ~/Documents/GitHub/Coursework/energy_monitor/.venv/lib/python3.12/site-packages/altair/utils/data.py:157, in limit_rows(data, max_rows)
#     154     values = data
#     156 if max_rows is not None and len(values) > max_rows:
# --> 157     raise_max_rows_error()
#     159 return data
#
# File ~/Documents/GitHub/Coursework/energy_monitor/.venv/lib/python3.12/site-packages/altair/utils/data.py:140, in limit_rows.<locals>.raise_max_rows_error()
#     127 def raise_max_rows_error():
#     128     msg = (
#     129         "The number of rows in your dataset is greater "
#     130         f"than the maximum allowed ({max_rows}).\n\n"
#    (...)
#     138         "on how to plot large datasets."
#     139     )
# --> 140     raise MaxRowsError(msg)
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000).
#
# Try enabling the VegaFusion data transformer which raises this limit by pre-evaluating data
# transformations in Python.
#     >> import altair as alt
#     >> alt.data_transformers.enable("vegafusion")
#
# Or, see https://altair-viz.github.io/user_guide/large_datasets.html for additional information
# on how to plot large datasets.
# alt.Chart(...)

# %%
fuel_type_mapping = {
    "BIOMASS": "BIOMASS",
    "CCGT": "CCGT (Combined Cycle Gas Turbine)",
    "COAL": "COAL",
    "NPSHYD": "NPSHYD (Non-Pumped Storage Hydro)",
    "NUCLEAR": "NUCLEAR",
    "OCGT": "OCGT (Open Cycle Gas Turbine)",
    "OIL": "OIL",
    "OTHER": "OTHER",
    "PS": "PS (Pumped Storage Hydro)",
    "WIND": "WIND"
}

interconnector_mapping = {
    "INTELEC": "England(INTELEC)",
    "INTEW": "Wales(INTEW)",
    "INTFR": "France(INTFR)",
    "INTGRNL": "Greenland(INTGRNL)",
    "INTIFA2": "Ireland-Scotland(INTIFA2)",
    "INTIRL": "Ireland(INTIRL)",
    "INTNED": "Netherlands(INTNED)",
    "INTNEM": "Belgium(INTNEM)",
    "INTNSL": "Norway(INTNSL)",
    "INTVKL": "Denmark(INTVKL)"
}

# %%
fuel_types = ["BIOMASS", "CCGT", "COAL", "NPSHYD",
              "NUCLEAR", "OCGT", "OIL", "OTHER", "PS", "WIND"]
interconnectors = ["INTELEC", "INTEW", "INTFR", "INTGRNL",
                   "INTIFA2", "INTIRL", "INTNED", "INTNEM", "INTNSL", "INTVKL"]
df_fuel_types = Gen_df[Gen_df['fuel_type'].isin(fuel_type_mapping.keys())].copy()
df_fuel_types['fuel_type'] = df_fuel_types['fuel_type'].map(fuel_type_mapping)


df_interconnectors = Gen_df[Gen_df['fuel_type'].isin(interconnector_mapping)].copy()
df_interconnectors['fuel_type'] = df_interconnectors['fuel_type'].map(interconnector_mapping)
df_interconnectors.rename(columns={'fuel_type': 'country'}, inplace=True)

# %%
chart = alt.Chart(df_fuel_types[["publish_time", "generated", "fuel_type"]]).mark_line().encode(
    x="publish_time", y="generated", color="fuel_type")
chart
# Out:
# alt.Chart(...)

# %%
chart = alt.Chart(df_interconnectors[["publish_time", "generated", "country"]]).mark_line().encode(
    x="publish_time", y="generated", color="country")
chart
# Out:
# alt.Chart(...)

# %%
carbon_chart = alt.Chart(carbon_df).mark_line().encode(alt.X('publish_time:T', title='Time'),
            y=alt.Y('forecast:Q', title='Carbon Forecast'))

carbon_chart
# Out:
# alt.Chart(...)

# %%
demand_chart = alt.Chart(Demand_df).mark_line().encode(alt.X('publish_time:T', title='Time'),
                                                       y=alt.Y('demand_amt:Q', title='Demand'))
demand_chart
# Out:
# alt.Chart(...)

# %%
carbon_chart_bar = alt.Chart(carbon_df).mark_bar().encode(alt.X('publish_time:T', title='Time'),
                                                       y=alt.Y('forecast:Q', title='Carbon Forecast'),color='carbon_level')
carbon_chart_bar
# Out:
# alt.Chart(...)
